# %%
# !rm -rf ~/.local/share/Trash/*

# %%
# !rm /root/rstab/zero_shot_0.wav
# !rm /root/rstab/zero_shot_1.wav
# !rm /root/rstab/zero_shot_2.wav
# !rm /root/rstab/zero_shot_3.wav
# !rm /root/rstab/cosy_mp3_chunks/*

# !rm -rf ~/.local/share/Trash/*
# Out:
# rm: cannot remove '/root/CosyVoice/zero_shot_0.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_1.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_2.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_3.wav': No such file or directory

# %% [raw]
# source /root/cosy/bin/activate

# %%
#!python combine_all_wavs_into_a_single_wav.py

from IPython.display import Audio, display
import os

# audio_file_path = os.path.expanduser('~/rstab/combined_audio.wav')
# audio_file_path = os.path.expanduser('~/rstab/output.mp3')
# audio_file_path = os.path.expanduser('~/rstab/test.wav')

audio_file_path = os.path.expanduser('/root/rstab/zero_shot_0.wav')
# audio_file_path = os.path.expanduser('/root/rstab/zero_shot_1.wav')
# audio_file_path = os.path.expanduser('/root/rstab/zero_shot_2.wav')
# audio_file_path = os.path.expanduser('/root/rstab/zero_shot_3.wav')



# Check if the file exists before trying to play it
if os.path.exists(audio_file_path):
    print(f"Playing audio from: {audio_file_path}")
    display(Audio(audio_file_path))
else:
    print(f"Error: Audio file not found at {audio_file_path}")
    print("Please ensure the file path is correct and the file exists.")

# %% [markdown]
# # Image history

# %% [markdown]
# docker login d.watchfun.cn
# docker login
#
# (save-image)
# // Save for WQ docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}"
#
# // Save for Docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}"
#
# (push-image-only)
# // Save to WQ docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker push "${image_name}:${tag}"
#
# // Save to Docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker push "${image_name}:${tag}"
#
# (save-and-push-image)
# // Save and push to WQ docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}" && docker push "${image_name}:${tag}"
#
# // Save and push to Docker repository
# version="1.1.1" && server_name="rstab" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}" && docker push "${image_name}:${tag}"
#
# (docker pull)
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker pull "${image_name}:${tag}"
#
# (start-docker)
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:7860 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=24g -w /root/RStab -v ~/rstab-volume/RStab_core/pretrained:/root/RStab/RStab_core/pretrained -v ~/rstab-volume/input:/root/RStab/input -v ~/rstab-volume/output:/root/RStab/output --name "${server_name}" "${image_name}:${tag}"
#
# //(deprecated)
# version="1.1.1" && server_name="rstab" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:7860 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=24g -w /root/rstab --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py --port 9001; /bin/bash"
#
# (Push my Docker Hub)[for unverisal docker image]
# docker commit --pause=false rstab jims57/ubuntu22.04-with-conda:pytorch1.11-0-cu113-git
# docker push jims57/ubuntu22.04-with-conda:pytorch1.11-0-cu113-git
#
# (Push my Watchfun Docker Hub)[for unverisal docker image]
# docker commit --pause=false rstab d.watchfun.cn/jims57/ubuntu22.04-with-conda:pytorch1.11-0-cu113-git
# docker push d.watchfun.cn/jims57/ubuntu22.04-with-conda:pytorch1.11-0-cu113-git
#
# v1.1.2:
#     *
# v1.1.1:
#     * install requirement.txt of rstab project successfully
#     * bugfix: Your CUDA environment is invalid
#     * install gcc
# v1.1.0:
#     * git clone rstab repository to /root folder
# v1.0.2:
#     * install git
# v1.0.1:
#     * install pytorch1.11.0+cu113 in the rstab conda env
# v1.0.0:
#     * install conda based on ubuntu 22.04

# %% [markdown]
# # run multi docker containers

# %% [markdown]
# docker login d.watchfun.cn
#
# version="1.1.1"
# server_name="rstab"
# image_prefix="d.watchfun.cn/jims57"
# image_name="${image_prefix}/rstab"
# tag="v${version}"
#
#
# ==== (auto starting api) ====
# docker rm "rstab-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/rstab --name "rstab-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py --port 9001; /bin/bash"
#
# docker rm "rstab-2" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="4-7" -p 9002:9002 --shm-size=3g -w /root/rstab --name "rstab-2" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py --port 9002; /bin/bash"
#
# docker rm "rstab-3" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="8-11" -p 9003:9003 --shm-size=3g -w /root/rstab --name "rstab-3" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py --port 9003; /bin/bash"
#
# docker rm "rstab-4" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="12-15" -p 9004:9004 --shm-size=3g -w /root/rstab --name "rstab-4" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py --port 9004; /bin/bash"
#
#
# ==== (run with auto starting api)
# docker rm "rstab-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/rstab --name "rstab-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "rstab-2" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="4-7" -p 9002:9002 --shm-size=3g -w /root/rstab --name "rstab-2" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "rstab-3" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="8-11" -p 9003:9003 --shm-size=3g -w /root/rstab --name "rstab-3" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "rstab-4" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="12-15" -p 9004:9004 --shm-size=3g -w /root/rstab --name "rstab-4" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"

# %% [markdown]
# # Other notes

# %% [raw]
# source ~/rstab/bin/activate
#
# (usage)
# ~/rstab/bin/python basicsr/demo.py -opt options/test/SIDD/rstab-width64.yml --input_path ./demo/noisy.png --output_path ./demo/denoise_img.png
# ~/rstab/bin/python basicsr/demo.py -opt options/test/SIDD/rstab-width64.yml --input_path ./demo/castle-cropped-256.png --output_path ./demo/denoise_castle-cropped-256.png
#
# ~/rstab/bin/python basicsr/demo.py -opt options/test/SIDD/rstab-width64.yml --input_path ./demo/20251022180831_124_25.jpg --output_path ./demo/denoise-20251022180831_124_25.jpg
#
# (run cosy api)
# cd ~/rstab && rm pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9001
# cd ~/rstab &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9001
#
# cd ~/rstab && rm pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9002
# cd ~/rstab &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9002
#
# cd ~/rstab && rm pretrained_models/rstab2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9003
# cd ~/rstab &&/root/rstab/cosy_vllm/bin/python cosy-api.py --port 9003
#
# cd ~/rstab && /root/rstab/cosy_vllm/bin/python cosy-api.py

# %%
import struct

# 将十六进制转换回数字
header_hex = "00000198 112CDE08 0001E240"
header_bytes = bytes.fromhex(header_hex)

# 解析（大端序格式）
parsed_start_time_id = struct.unpack('>Q', header_bytes[:8])[0]
parsed_message_id = struct.unpack('>I', header_bytes[8:12])[0]

print(f"Parsed startTimeId: {parsed_start_time_id}")  # 应该是 1752634739864
print(f"Parsed messageId: {parsed_message_id}")      # 应该是 12345678
# Out:
# Parsed startTimeId: 1752634809864
# Parsed messageId: 123456
